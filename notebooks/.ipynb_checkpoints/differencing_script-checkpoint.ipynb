# %%
"""
lidar_pipeline.py

A unified pipeline for LiDAR metric differencing, overview generation, and VRT construction.
This module can be imported into Jupyter or run as a script without needing CLI arguments; simply modify the
configuration at the bottom of this file and call `run()`.
"""
import os
import glob
import subprocess
import time
import traceback
# Out:
# Done: 0 processed, 0 skipped.
# Done: 0 processed, 0 skipped.
# Done: 0 processed, 0 skipped.
# Skipping 449000_3802000: no match in second folder.
# Skipping 449000_3803000: no match in second folder.
# Skipping 449000_3804000: no match in second folder.
# Skipping 449000_3805000: no match in second folder.
# Skipping 449000_3806000: no match in second folder.
# Skipping 449000_3807000: no match in second folder.
# Skipping 449000_3808000: no match in second folder.
# Skipping 450000_3798000: no match in second folder.
# Skipping 450000_3799000: no match in second folder.
# Skipping 450000_3800000: no match in second folder.
# Skipping 450000_3801000: no match in second folder.
# Skipping 450000_3802000: no match in second folder.
# Skipping 450000_3803000: no match in second folder.
# Skipping 450000_3804000: no match in second folder.
# Skipping 450000_3805000: no match in second folder.
# Skipping 450000_3806000: no match in second folder.
# Processed 450000_3807000 (dsm).
# Processed 450000_3808000 (dsm).
# Skipping 451000_3794000: no match in second folder.
# Skipping 451000_3795000: no match in second folder.
# Skipping 451000_3796000: no match in second folder.
# Skipping 451000_3797000: no match in second folder.
# Skipping 451000_3798000: no match in second folder.
# Skipping 451000_3799000: no match in second folder.
# Skipping 451000_3800000: no match in second folder.
# Skipping 451000_3801000: no match in second folder.
# Skipping 451000_3802000: no match in second folder.
# Skipping 451000_3803000: no match in second folder.
# Skipping 451000_3804000: no match in second folder.
# Skipping 451000_3805000: no match in second folder.
# Skipping 451000_3806000: no match in second folder.
# Processed 451000_3807000 (dsm).
# Processed 451000_3808000 (dsm).
# Skipping 452000_3790000: no match in second folder.
# Skipping 452000_3791000: no match in second folder.
# Skipping 452000_3792000: no match in second folder.
# Skipping 452000_3793000: no match in second folder.
# Skipping 452000_3794000: no match in second folder.
# Skipping 452000_3795000: no match in second folder.
# Skipping 452000_3796000: no match in second folder.
# Skipping 452000_3797000: no match in second folder.
# Skipping 452000_3798000: no match in second folder.
# Skipping 452000_3799000: no match in second folder.
# Skipping 452000_3800000: no match in second folder.
# Skipping 452000_3801000: no match in second folder.
# Skipping 452000_3802000: no match in second folder.
# Skipping 452000_3803000: no match in second folder.
# Skipping 452000_3804000: no match in second folder.
# Skipping 452000_3805000: no match in second folder.
# Skipping 452000_3806000: no match in second folder.
# Processed 452000_3807000 (dsm).
# Processed 452000_3808000 (dsm).
# Skipping 453000_3786000: no match in second folder.
# Skipping 453000_3787000: no match in second folder.
# Skipping 453000_3788000: no match in second folder.
# Skipping 453000_3789000: no match in second folder.
# Skipping 453000_3790000: no match in second folder.
# Skipping 453000_3791000: no match in second folder.
# Skipping 453000_3792000: no match in second folder.
# Skipping 453000_3793000: no match in second folder.
# Skipping 453000_3794000: no match in second folder.
# Skipping 453000_3795000: no match in second folder.
# Skipping 453000_3796000: no match in second folder.
# Skipping 453000_3797000: no match in second folder.
# Skipping 453000_3798000: no match in second folder.
# Skipping 453000_3799000: no match in second folder.
# Skipping 453000_3800000: no match in second folder.
# Skipping 453000_3801000: no match in second folder.
# Skipping 453000_3802000: no match in second folder.
# Skipping 453000_3803000: no match in second folder.
# Skipping 453000_3804000: no match in second folder.
# Skipping 453000_3805000: no match in second folder.
# Skipping 453000_3806000: no match in second folder.
# Skipping 453000_3807000: no match in second folder.
# Processed 453000_3808000 (dsm).
# Processed 453000_3809000 (dsm).
# Skipping 454000_3776000: no match in second folder.
# Skipping 454000_3777000: no match in second folder.
# Skipping 454000_3782000: no match in second folder.
# Skipping 454000_3783000: no match in second folder.
# Skipping 454000_3784000: no match in second folder.
# Skipping 454000_3785000: no match in second folder.
# Skipping 454000_3786000: no match in second folder.
# Skipping 454000_3787000: no match in second folder.
# Skipping 454000_3788000: no match in second folder.
# Skipping 454000_3789000: no match in second folder.
# Skipping 454000_3790000: no match in second folder.
# Skipping 454000_3791000: no match in second folder.
# Skipping 454000_3792000: no match in second folder.
# Skipping 454000_3793000: no match in second folder.
# Skipping 454000_3794000: no match in second folder.
# Skipping 454000_3795000: no match in second folder.
# Skipping 454000_3796000: no match in second folder.
# Skipping 454000_3797000: no match in second folder.
# Skipping 454000_3798000: no match in second folder.
# Skipping 454000_3799000: no match in second folder.
# Skipping 454000_3800000: no match in second folder.
# Skipping 454000_3801000: no match in second folder.
# Skipping 454000_3802000: no match in second folder.
# Skipping 454000_3803000: no match in second folder.
# Skipping 454000_3804000: no match in second folder.
# Skipping 454000_3805000: no match in second folder.
# Skipping 454000_3806000: no match in second folder.
# Processed 454000_3807000 (dsm).
# Processed 454000_3808000 (dsm).
# Processed 454000_3809000 (dsm).
# Processed 454000_3810000 (dsm).
# Skipping 455000_3771000: no match in second folder.
# Skipping 455000_3772000: no match in second folder.
# Skipping 455000_3773000: no match in second folder.
# Skipping 455000_3774000: no match in second folder.
# Skipping 455000_3775000: no match in second folder.
# Skipping 455000_3776000: no match in second folder.
# Skipping 455000_3777000: no match in second folder.
# Skipping 455000_3778000: no match in second folder.
# Skipping 455000_3779000: no match in second folder.
# Skipping 455000_3780000: no match in second folder.
# Skipping 455000_3781000: no match in second folder.
# Skipping 455000_3782000: no match in second folder.
# Skipping 455000_3783000: no match in second folder.
# Skipping 455000_3784000: no match in second folder.
# Skipping 455000_3785000: no match in second folder.
# Skipping 455000_3786000: no match in second folder.
# Skipping 455000_3787000: no match in second folder.
# Skipping 455000_3788000: no match in second folder.
# Skipping 455000_3789000: no match in second folder.
# Skipping 455000_3790000: no match in second folder.
# Skipping 455000_3791000: no match in second folder.
# Skipping 455000_3792000: no match in second folder.
# Skipping 455000_3793000: no match in second folder.
# Skipping 455000_3794000: no match in second folder.
# Skipping 455000_3795000: no match in second folder.
# Skipping 455000_3796000: no match in second folder.
# Skipping 455000_3797000: no match in second folder.
# Skipping 455000_3798000: no match in second folder.
# Skipping 455000_3799000: no match in second folder.
# Skipping 455000_3800000: no match in second folder.
# Skipping 455000_3801000: no match in second folder.
# Skipping 455000_3802000: no match in second folder.
# Skipping 455000_3803000: no match in second folder.
# Skipping 455000_3804000: no match in second folder.
# Skipping 455000_3805000: no match in second folder.
# Skipping 455000_3806000: no match in second folder.
# Processed 455000_3807000 (dsm).
# Processed 455000_3808000 (dsm).
# Processed 455000_3809000 (dsm).
# Processed 455000_3810000 (dsm).
# Skipping 456000_3771000: no match in second folder.
# Skipping 456000_3772000: no match in second folder.
# Skipping 456000_3773000: no match in second folder.
# Skipping 456000_3774000: no match in second folder.
# Skipping 456000_3775000: no match in second folder.
# Skipping 456000_3776000: no match in second folder.
# Skipping 456000_3777000: no match in second folder.
# Skipping 456000_3778000: no match in second folder.
# Skipping 456000_3779000: no match in second folder.
# Skipping 456000_3780000: no match in second folder.
# Skipping 456000_3781000: no match in second folder.
# Skipping 456000_3782000: no match in second folder.
# Skipping 456000_3783000: no match in second folder.
# Skipping 456000_3784000: no match in second folder.
# Skipping 456000_3785000: no match in second folder.
# Skipping 456000_3786000: no match in second folder.
# Skipping 456000_3787000: no match in second folder.
# Skipping 456000_3788000: no match in second folder.
# Skipping 456000_3789000: no match in second folder.
# Skipping 456000_3790000: no match in second folder.
# Skipping 456000_3791000: no match in second folder.
# Skipping 456000_3792000: no match in second folder.
# Skipping 456000_3793000: no match in second folder.
# Skipping 456000_3794000: no match in second folder.
# Skipping 456000_3795000: no match in second folder.
# Skipping 456000_3796000: no match in second folder.
# Skipping 456000_3797000: no match in second folder.
# Skipping 456000_3798000: no match in second folder.
# Skipping 456000_3799000: no match in second folder.
# Skipping 456000_3800000: no match in second folder.
# Skipping 456000_3801000: no match in second folder.
# Skipping 456000_3802000: no match in second folder.
# Skipping 456000_3803000: no match in second folder.
# Skipping 456000_3804000: no match in second folder.
# Skipping 456000_3805000: no match in second folder.
# Skipping 456000_3806000: no match in second folder.
# Processed 456000_3807000 (dsm).
# Processed 456000_3808000 (dsm).
# Processed 456000_3809000 (dsm).
# Processed 456000_3810000 (dsm).
# Skipping 457000_3771000: no match in second folder.
# Skipping 457000_3772000: no match in second folder.
# Skipping 457000_3773000: no match in second folder.
# Skipping 457000_3774000: no match in second folder.
# Skipping 457000_3775000: no match in second folder.
# Skipping 457000_3776000: no match in second folder.
# Skipping 457000_3777000: no match in second folder.
# Skipping 457000_3778000: no match in second folder.
# Skipping 457000_3779000: no match in second folder.
# Skipping 457000_3780000: no match in second folder.
# Skipping 457000_3781000: no match in second folder.
# Skipping 457000_3782000: no match in second folder.
# Skipping 457000_3783000: no match in second folder.
# Skipping 457000_3784000: no match in second folder.
# Skipping 457000_3785000: no match in second folder.
# Skipping 457000_3786000: no match in second folder.
# Skipping 457000_3787000: no match in second folder.
# Skipping 457000_3788000: no match in second folder.
# Skipping 457000_3789000: no match in second folder.
# Skipping 457000_3790000: no match in second folder.
# Skipping 457000_3791000: no match in second folder.
# Skipping 457000_3792000: no match in second folder.
# Skipping 457000_3793000: no match in second folder.
# Skipping 457000_3794000: no match in second folder.
# Skipping 457000_3795000: no match in second folder.
# Skipping 457000_3796000: no match in second folder.
# Skipping 457000_3797000: no match in second folder.
# Skipping 457000_3798000: no match in second folder.
# Skipping 457000_3799000: no match in second folder.
# Skipping 457000_3800000: no match in second folder.
# Skipping 457000_3801000: no match in second folder.
# Skipping 457000_3802000: no match in second folder.
# Skipping 457000_3803000: no match in second folder.
# Skipping 457000_3804000: no match in second folder.
# Skipping 457000_3805000: no match in second folder.
# Skipping 457000_3806000: no match in second folder.
# Processed 457000_3807000 (dsm).
# Processed 457000_3808000 (dsm).
# Processed 457000_3809000 (dsm).
# Processed 457000_3810000 (dsm).
# Skipping 458000_3771000: no match in second folder.
# Skipping 458000_3772000: no match in second folder.
# Skipping 458000_3773000: no match in second folder.
# Skipping 458000_3774000: no match in second folder.
# Skipping 458000_3775000: no match in second folder.
# Skipping 458000_3776000: no match in second folder.
# Skipping 458000_3777000: no match in second folder.
# Skipping 458000_3778000: no match in second folder.
# Skipping 458000_3779000: no match in second folder.
# Skipping 458000_3780000: no match in second folder.
# Skipping 458000_3781000: no match in second folder.
# Skipping 458000_3782000: no match in second folder.
# Skipping 458000_3783000: no match in second folder.
# Skipping 458000_3784000: no match in second folder.
# Skipping 458000_3785000: no match in second folder.
# Skipping 458000_3786000: no match in second folder.
# Skipping 458000_3787000: no match in second folder.
# Skipping 458000_3788000: no match in second folder.
# Skipping 458000_3789000: no match in second folder.
# Skipping 458000_3790000: no match in second folder.
# Skipping 458000_3791000: no match in second folder.
# Skipping 458000_3792000: no match in second folder.
# Skipping 458000_3793000: no match in second folder.
# Skipping 458000_3794000: no match in second folder.
# Skipping 458000_3795000: no match in second folder.
# Skipping 458000_3796000: no match in second folder.
# Skipping 458000_3797000: no match in second folder.
# Skipping 458000_3798000: no match in second folder.
# Skipping 458000_3799000: no match in second folder.
# Skipping 458000_3800000: no match in second folder.
# Skipping 458000_3801000: no match in second folder.
# Skipping 458000_3802000: no match in second folder.
# Processed 458000_3803000 (dsm).
# Processed 458000_3804000 (dsm).
# Skipping 458000_3805000: no match in second folder.
# Skipping 458000_3806000: no match in second folder.
# Skipping 458000_3807000: no match in second folder.
# Processed 458000_3808000 (dsm).
# Processed 458000_3809000 (dsm).
# Processed 458000_3810000 (dsm).
# Skipping 459000_3771000: no match in second folder.
# Skipping 459000_3772000: no match in second folder.
# Skipping 459000_3773000: no match in second folder.
# Skipping 459000_3774000: no match in second folder.
# Skipping 459000_3775000: no match in second folder.
# Skipping 459000_3776000: no match in second folder.
# Skipping 459000_3777000: no match in second folder.
# Skipping 459000_3778000: no match in second folder.
# Skipping 459000_3779000: no match in second folder.
# Skipping 459000_3780000: no match in second folder.
# Skipping 459000_3781000: no match in second folder.
# Skipping 459000_3782000: no match in second folder.
# Skipping 459000_3783000: no match in second folder.
# Skipping 459000_3784000: no match in second folder.
# Skipping 459000_3785000: no match in second folder.
# Skipping 459000_3786000: no match in second folder.
# Skipping 459000_3787000: no match in second folder.
# Skipping 459000_3788000: no match in second folder.
# Skipping 459000_3789000: no match in second folder.
# Skipping 459000_3790000: no match in second folder.
# Skipping 459000_3791000: no match in second folder.
# Skipping 459000_3792000: no match in second folder.
# Skipping 459000_3793000: no match in second folder.
# Skipping 459000_3794000: no match in second folder.
# Skipping 459000_3795000: no match in second folder.
# Skipping 459000_3796000: no match in second folder.
# Skipping 459000_3797000: no match in second folder.
# Skipping 459000_3798000: no match in second folder.
# Skipping 459000_3799000: no match in second folder.
# Skipping 459000_3800000: no match in second folder.
# Skipping 459000_3801000: no match in second folder.
# Processed 459000_3802000 (dsm).
# Processed 459000_3803000 (dsm).
# Processed 459000_3804000 (dsm).
# Processed 459000_3805000 (dsm).
# Processed 459000_3806000 (dsm).
# Processed 459000_3807000 (dsm).
# Processed 459000_3808000 (dsm).
# Processed 459000_3809000 (dsm).
# Processed 459000_3810000 (dsm).
# Processed 459000_3811000 (dsm).
# Skipping 460000_3771000: no match in second folder.
# Skipping 460000_3772000: no match in second folder.
# Skipping 460000_3773000: no match in second folder.
# Skipping 460000_3774000: no match in second folder.
# Skipping 460000_3775000: no match in second folder.
# Skipping 460000_3776000: no match in second folder.
# Skipping 460000_3777000: no match in second folder.
# Skipping 460000_3778000: no match in second folder.
# Skipping 460000_3779000: no match in second folder.
# Skipping 460000_3780000: no match in second folder.
# Skipping 460000_3781000: no match in second folder.
# Skipping 460000_3782000: no match in second folder.
# Skipping 460000_3783000: no match in second folder.
# Skipping 460000_3784000: no match in second folder.
# Skipping 460000_3785000: no match in second folder.
# Skipping 460000_3786000: no match in second folder.
# Skipping 460000_3787000: no match in second folder.
# Skipping 460000_3788000: no match in second folder.
# Skipping 460000_3789000: no match in second folder.
# Skipping 460000_3790000: no match in second folder.
# Skipping 460000_3791000: no match in second folder.
# Skipping 460000_3792000: no match in second folder.
# Skipping 460000_3793000: no match in second folder.
# Skipping 460000_3794000: no match in second folder.
# Skipping 460000_3795000: no match in second folder.
# Skipping 460000_3796000: no match in second folder.
# Skipping 460000_3797000: no match in second folder.
# Skipping 460000_3798000: no match in second folder.
# Skipping 460000_3799000: no match in second folder.
# Skipping 460000_3800000: no match in second folder.
# Processed 460000_3801000 (dsm).
# Processed 460000_3802000 (dsm).
# Processed 460000_3803000 (dsm).
# Processed 460000_3804000 (dsm).
# Processed 460000_3805000 (dsm).
# Processed 460000_3806000 (dsm).
# Processed 460000_3807000 (dsm).
# Processed 460000_3808000 (dsm).
# Processed 460000_3809000 (dsm).
# Processed 460000_3810000 (dsm).
# Processed 460000_3811000 (dsm).
# Processed 460000_3812000 (dsm).
# Skipping 461000_3771000: no match in second folder.
# Skipping 461000_3772000: no match in second folder.
# Skipping 461000_3773000: no match in second folder.
# Skipping 461000_3774000: no match in second folder.
# Skipping 461000_3775000: no match in second folder.
# Skipping 461000_3776000: no match in second folder.
# Skipping 461000_3777000: no match in second folder.
# Skipping 461000_3778000: no match in second folder.
# Skipping 461000_3779000: no match in second folder.
# Skipping 461000_3780000: no match in second folder.
# Skipping 461000_3781000: no match in second folder.
# Skipping 461000_3782000: no match in second folder.
# Skipping 461000_3783000: no match in second folder.
# Skipping 461000_3784000: no match in second folder.
# Skipping 461000_3785000: no match in second folder.
# Skipping 461000_3786000: no match in second folder.
# Skipping 461000_3787000: no match in second folder.
# Skipping 461000_3788000: no match in second folder.
# Skipping 461000_3789000: no match in second folder.
# Skipping 461000_3790000: no match in second folder.
# Skipping 461000_3791000: no match in second folder.
# Skipping 461000_3792000: no match in second folder.
# Skipping 461000_3793000: no match in second folder.
# Skipping 461000_3794000: no match in second folder.
# Skipping 461000_3795000: no match in second folder.
# Skipping 461000_3796000: no match in second folder.
# Skipping 461000_3797000: no match in second folder.
# Skipping 461000_3798000: no match in second folder.
# Skipping 461000_3799000: no match in second folder.
# Skipping 461000_3800000: no match in second folder.
# Processed 461000_3801000 (dsm).
# Processed 461000_3802000 (dsm).
# Processed 461000_3803000 (dsm).
# Processed 461000_3804000 (dsm).
# Processed 461000_3805000 (dsm).
# Processed 461000_3806000 (dsm).
# Processed 461000_3807000 (dsm).
# Processed 461000_3808000 (dsm).
# Processed 461000_3809000 (dsm).
# Processed 461000_3810000 (dsm).
# Processed 461000_3811000 (dsm).
# Skipping 462000_3771000: no match in second folder.
# Skipping 462000_3772000: no match in second folder.
# Skipping 462000_3773000: no match in second folder.
# Skipping 462000_3774000: no match in second folder.
# Skipping 462000_3775000: no match in second folder.
# Skipping 462000_3776000: no match in second folder.
# Skipping 462000_3777000: no match in second folder.
# Skipping 462000_3778000: no match in second folder.
# Skipping 462000_3779000: no match in second folder.
# Skipping 462000_3780000: no match in second folder.
# Skipping 462000_3781000: no match in second folder.
# Skipping 462000_3782000: no match in second folder.
# Skipping 462000_3783000: no match in second folder.
# Skipping 462000_3784000: no match in second folder.
# Skipping 462000_3785000: no match in second folder.
# Skipping 462000_3786000: no match in second folder.
# Skipping 462000_3787000: no match in second folder.
# Skipping 462000_3788000: no match in second folder.
# Skipping 462000_3789000: no match in second folder.
# Skipping 462000_3790000: no match in second folder.
# Skipping 462000_3791000: no match in second folder.
# Skipping 462000_3792000: no match in second folder.
# Skipping 462000_3793000: no match in second folder.
# Skipping 462000_3794000: no match in second folder.
# Skipping 462000_3795000: no match in second folder.
# Skipping 462000_3796000: no match in second folder.
# Skipping 462000_3797000: no match in second folder.
# Skipping 462000_3798000: no match in second folder.
# Skipping 462000_3799000: no match in second folder.
# Skipping 462000_3800000: no match in second folder.
# Processed 462000_3801000 (dsm).
# Processed 462000_3802000 (dsm).
# Processed 462000_3803000 (dsm).
# Processed 462000_3804000 (dsm).
# Processed 462000_3806000 (dsm).
# Processed 462000_3807000 (dsm).
# Processed 462000_3809000 (dsm).
# Processed 462000_3810000 (dsm).
# Processed 462000_3811000 (dsm).
# Skipping 463000_3771000: no match in second folder.
# Skipping 463000_3772000: no match in second folder.
# Skipping 463000_3773000: no match in second folder.
# Skipping 463000_3774000: no match in second folder.
# Skipping 463000_3775000: no match in second folder.
# Skipping 463000_3776000: no match in second folder.
# Skipping 463000_3777000: no match in second folder.
# Skipping 463000_3778000: no match in second folder.
# Skipping 463000_3779000: no match in second folder.
# Skipping 463000_3780000: no match in second folder.
# Skipping 463000_3781000: no match in second folder.
# Skipping 463000_3782000: no match in second folder.
# Skipping 463000_3783000: no match in second folder.
# Skipping 463000_3784000: no match in second folder.
# Skipping 463000_3785000: no match in second folder.
# Skipping 463000_3786000: no match in second folder.
# Skipping 463000_3787000: no match in second folder.
# Skipping 463000_3788000: no match in second folder.
# Skipping 463000_3789000: no match in second folder.
# Skipping 463000_3790000: no match in second folder.
# Skipping 463000_3791000: no match in second folder.
# Skipping 463000_3792000: no match in second folder.
# Skipping 463000_3793000: no match in second folder.
# Skipping 463000_3794000: no match in second folder.
# Skipping 463000_3795000: no match in second folder.
# Skipping 463000_3796000: no match in second folder.
# Skipping 463000_3797000: no match in second folder.
# Skipping 463000_3798000: no match in second folder.
# Skipping 463000_3799000: no match in second folder.
# Skipping 463000_3800000: no match in second folder.
# Processed 463000_3801000 (dsm).
# Processed 463000_3802000 (dsm).
# Processed 463000_3803000 (dsm).
# Processed 463000_3804000 (dsm).
# Processed 463000_3805000 (dsm).
# Processed 463000_3806000 (dsm).
# Processed 463000_3807000 (dsm).
# Processed 463000_3808000 (dsm).
# Processed 463000_3809000 (dsm).
# Processed 463000_3810000 (dsm).
# Processed 463000_3811000 (dsm).
# Skipping 464000_3771000: no match in second folder.
# Skipping 464000_3772000: no match in second folder.
# Skipping 464000_3773000: no match in second folder.
# Skipping 464000_3774000: no match in second folder.
# Skipping 464000_3775000: no match in second folder.
# Skipping 464000_3776000: no match in second folder.
# Skipping 464000_3777000: no match in second folder.
# Skipping 464000_3778000: no match in second folder.
# Skipping 464000_3779000: no match in second folder.
# Skipping 464000_3780000: no match in second folder.
# Skipping 464000_3781000: no match in second folder.
# Skipping 464000_3782000: no match in second folder.
# Skipping 464000_3783000: no match in second folder.
# Skipping 464000_3784000: no match in second folder.
# Skipping 464000_3785000: no match in second folder.
# Skipping 464000_3786000: no match in second folder.
# Skipping 464000_3787000: no match in second folder.
# Skipping 464000_3788000: no match in second folder.
# Skipping 464000_3789000: no match in second folder.
# Skipping 464000_3790000: no match in second folder.
# Skipping 464000_3791000: no match in second folder.
# Skipping 464000_3792000: no match in second folder.
# Skipping 464000_3793000: no match in second folder.
# Skipping 464000_3794000: no match in second folder.
# Skipping 464000_3795000: no match in second folder.
# Skipping 464000_3796000: no match in second folder.
# Skipping 464000_3797000: no match in second folder.
# Skipping 464000_3798000: no match in second folder.
# Skipping 464000_3799000: no match in second folder.
# Skipping 464000_3800000: no match in second folder.
# Processed 464000_3801000 (dsm).
# Processed 464000_3802000 (dsm).
# Processed 464000_3803000 (dsm).
# Processed 464000_3804000 (dsm).
# Processed 464000_3805000 (dsm).
# Processed 464000_3806000 (dsm).
# Processed 464000_3807000 (dsm).
# Processed 464000_3808000 (dsm).
# Processed 464000_3809000 (dsm).
# Processed 464000_3810000 (dsm).
# Skipping 465000_3771000: no match in second folder.
# Skipping 465000_3772000: no match in second folder.
# Skipping 465000_3773000: no match in second folder.
# Skipping 465000_3774000: no match in second folder.
# Skipping 465000_3775000: no match in second folder.
# Skipping 465000_3776000: no match in second folder.
# Skipping 465000_3777000: no match in second folder.
# Skipping 465000_3778000: no match in second folder.
# Skipping 465000_3779000: no match in second folder.
# Skipping 465000_3780000: no match in second folder.
# Skipping 465000_3781000: no match in second folder.
# Skipping 465000_3782000: no match in second folder.
# Skipping 465000_3783000: no match in second folder.
# Skipping 465000_3784000: no match in second folder.
# Skipping 465000_3785000: no match in second folder.
# Skipping 465000_3786000: no match in second folder.
# Skipping 465000_3787000: no match in second folder.
# Skipping 465000_3788000: no match in second folder.
# Skipping 465000_3789000: no match in second folder.
# Skipping 465000_3790000: no match in second folder.
# Skipping 465000_3791000: no match in second folder.
# Skipping 465000_3792000: no match in second folder.
# Skipping 465000_3793000: no match in second folder.
# Skipping 465000_3794000: no match in second folder.
# Skipping 465000_3795000: no match in second folder.
# Skipping 465000_3796000: no match in second folder.
# Skipping 465000_3797000: no match in second folder.
# Skipping 465000_3798000: no match in second folder.
# Skipping 465000_3799000: no match in second folder.
# Skipping 465000_3800000: no match in second folder.
# Skipping 465000_3801000: no match in second folder.
# Processed 465000_3802000 (dsm).
# Processed 465000_3803000 (dsm).
# Processed 465000_3804000 (dsm).
# Processed 465000_3805000 (dsm).
# Processed 465000_3806000 (dsm).
# Processed 465000_3807000 (dsm).
# Processed 465000_3808000 (dsm).
# Processed 465000_3809000 (dsm).
# Processed 465000_3810000 (dsm).
# Processed 465000_3811000 (dsm).
# Skipping 466000_3771000: no match in second folder.
# Skipping 466000_3772000: no match in second folder.
# Skipping 466000_3773000: no match in second folder.
# Skipping 466000_3774000: no match in second folder.
# Skipping 466000_3775000: no match in second folder.
# Skipping 466000_3776000: no match in second folder.
# Skipping 466000_3777000: no match in second folder.
# Skipping 466000_3778000: no match in second folder.
# Skipping 466000_3779000: no match in second folder.
# Skipping 466000_3780000: no match in second folder.
# Skipping 466000_3781000: no match in second folder.
# Skipping 466000_3782000: no match in second folder.
# Skipping 466000_3783000: no match in second folder.
# Skipping 466000_3784000: no match in second folder.
# Skipping 466000_3785000: no match in second folder.
# Skipping 466000_3786000: no match in second folder.
# Skipping 466000_3787000: no match in second folder.
# Skipping 466000_3788000: no match in second folder.
# Skipping 466000_3789000: no match in second folder.
# Skipping 466000_3790000: no match in second folder.
# Skipping 466000_3791000: no match in second folder.
# Skipping 466000_3792000: no match in second folder.
# Skipping 466000_3793000: no match in second folder.
# Skipping 466000_3794000: no match in second folder.
# Skipping 466000_3795000: no match in second folder.
# Skipping 466000_3796000: no match in second folder.
# Skipping 466000_3797000: no match in second folder.
# Skipping 466000_3798000: no match in second folder.
# Skipping 466000_3799000: no match in second folder.
# Skipping 466000_3800000: no match in second folder.
# Skipping 466000_3801000: no match in second folder.
# Skipping 466000_3802000: no match in second folder.
# Processed 466000_3803000 (dsm).
# Processed 466000_3804000 (dsm).
# Processed 466000_3805000 (dsm).
# Processed 466000_3806000 (dsm).
# Processed 466000_3807000 (dsm).
# Processed 466000_3808000 (dsm).
# Processed 466000_3809000 (dsm).
# Processed 466000_3810000 (dsm).
# Processed 466000_3811000 (dsm).
# Skipping 467000_3771000: no match in second folder.
# Skipping 467000_3772000: no match in second folder.
# Skipping 467000_3773000: no match in second folder.
# Skipping 467000_3774000: no match in second folder.
# Skipping 467000_3775000: no match in second folder.
# Skipping 467000_3776000: no match in second folder.
# Skipping 467000_3777000: no match in second folder.
# Skipping 467000_3778000: no match in second folder.
# Skipping 467000_3779000: no match in second folder.
# Skipping 467000_3780000: no match in second folder.
# Skipping 467000_3781000: no match in second folder.
# Skipping 467000_3782000: no match in second folder.
# Skipping 467000_3783000: no match in second folder.
# Skipping 467000_3784000: no match in second folder.
# Skipping 467000_3785000: no match in second folder.
# Skipping 467000_3786000: no match in second folder.
# Skipping 467000_3787000: no match in second folder.
# Skipping 467000_3788000: no match in second folder.
# Skipping 467000_3789000: no match in second folder.
# Skipping 467000_3790000: no match in second folder.
# Skipping 467000_3791000: no match in second folder.
# Skipping 467000_3792000: no match in second folder.
# Skipping 467000_3793000: no match in second folder.
# Skipping 467000_3794000: no match in second folder.
# Skipping 467000_3795000: no match in second folder.
# Skipping 467000_3796000: no match in second folder.
# Skipping 467000_3797000: no match in second folder.
# Skipping 467000_3798000: no match in second folder.
# Skipping 467000_3799000: no match in second folder.
# Skipping 467000_3800000: no match in second folder.
# Skipping 467000_3801000: no match in second folder.
# Skipping 467000_3802000: no match in second folder.
# Processed 467000_3803000 (dsm).
# Processed 467000_3804000 (dsm).
# Processed 467000_3805000 (dsm).
# Processed 467000_3806000 (dsm).
# Processed 467000_3807000 (dsm).
# Processed 467000_3808000 (dsm).
# Processed 467000_3809000 (dsm).
# Processed 467000_3810000 (dsm).
# Processed 467000_3811000 (dsm).
# Skipping 468000_3771000: no match in second folder.
# Skipping 468000_3772000: no match in second folder.
# Skipping 468000_3773000: no match in second folder.
# Skipping 468000_3774000: no match in second folder.
# Skipping 468000_3775000: no match in second folder.
# Skipping 468000_3776000: no match in second folder.
# Skipping 468000_3777000: no match in second folder.
# Skipping 468000_3778000: no match in second folder.
# Skipping 468000_3779000: no match in second folder.
# Skipping 468000_3780000: no match in second folder.
# Skipping 468000_3781000: no match in second folder.
# Skipping 468000_3782000: no match in second folder.
# Skipping 468000_3783000: no match in second folder.
# Skipping 468000_3784000: no match in second folder.
# Skipping 468000_3785000: no match in second folder.
# Skipping 468000_3786000: no match in second folder.
# Skipping 468000_3787000: no match in second folder.
# Skipping 468000_3788000: no match in second folder.
# Skipping 468000_3789000: no match in second folder.
# Skipping 468000_3790000: no match in second folder.
# Skipping 468000_3791000: no match in second folder.
# Skipping 468000_3792000: no match in second folder.
# Skipping 468000_3793000: no match in second folder.
# Skipping 468000_3794000: no match in second folder.
# Skipping 468000_3795000: no match in second folder.
# Skipping 468000_3796000: no match in second folder.
# Skipping 468000_3797000: no match in second folder.
# Skipping 468000_3798000: no match in second folder.
# Skipping 468000_3799000: no match in second folder.
# Skipping 468000_3800000: no match in second folder.
# Skipping 468000_3801000: no match in second folder.
# Skipping 468000_3802000: no match in second folder.
# Processed 468000_3803000 (dsm).
# Processed 468000_3804000 (dsm).
# Processed 468000_3805000 (dsm).
# Processed 468000_3806000 (dsm).
# Processed 468000_3807000 (dsm).
# Processed 468000_3808000 (dsm).
# Processed 468000_3809000 (dsm).
# Skipping 469000_3771000: no match in second folder.
# Skipping 469000_3772000: no match in second folder.
# Skipping 469000_3773000: no match in second folder.
# Skipping 469000_3774000: no match in second folder.
# Skipping 469000_3775000: no match in second folder.
# Skipping 469000_3776000: no match in second folder.
# Skipping 469000_3777000: no match in second folder.
# Skipping 469000_3778000: no match in second folder.
# Skipping 469000_3779000: no match in second folder.
# Skipping 469000_3780000: no match in second folder.
# Skipping 469000_3781000: no match in second folder.
# Skipping 469000_3782000: no match in second folder.
# Skipping 469000_3783000: no match in second folder.
# Skipping 469000_3784000: no match in second folder.
# Skipping 469000_3785000: no match in second folder.
# Skipping 469000_3786000: no match in second folder.
# Skipping 469000_3787000: no match in second folder.
# Skipping 469000_3788000: no match in second folder.
# Skipping 469000_3789000: no match in second folder.
# Skipping 469000_3790000: no match in second folder.
# Skipping 469000_3791000: no match in second folder.
# Skipping 469000_3792000: no match in second folder.
# Skipping 469000_3793000: no match in second folder.
# Skipping 469000_3794000: no match in second folder.
# Skipping 469000_3795000: no match in second folder.
# Skipping 469000_3796000: no match in second folder.
# Skipping 469000_3797000: no match in second folder.
# Skipping 469000_3798000: no match in second folder.
# Skipping 469000_3799000: no match in second folder.
# Skipping 469000_3800000: no match in second folder.
# Skipping 469000_3801000: no match in second folder.
# Skipping 469000_3802000: no match in second folder.
# Processed 469000_3803000 (dsm).
# Processed 469000_3804000 (dsm).
# Processed 469000_3805000 (dsm).
# Processed 469000_3806000 (dsm).
# Processed 469000_3807000 (dsm).
# Processed 469000_3808000 (dsm).
# Processed 469000_3809000 (dsm).
# Skipping 470000_3771000: no match in second folder.
# Skipping 470000_3772000: no match in second folder.
# Skipping 470000_3773000: no match in second folder.
# Skipping 470000_3774000: no match in second folder.
# Skipping 470000_3775000: no match in second folder.
# Skipping 470000_3776000: no match in second folder.
# Skipping 470000_3777000: no match in second folder.
# Skipping 470000_3778000: no match in second folder.
# Skipping 470000_3779000: no match in second folder.
# Skipping 470000_3780000: no match in second folder.
# Skipping 470000_3781000: no match in second folder.
# Skipping 470000_3782000: no match in second folder.
# Skipping 470000_3783000: no match in second folder.
# Skipping 470000_3784000: no match in second folder.
# Skipping 470000_3785000: no match in second folder.
# Skipping 470000_3786000: no match in second folder.
# Skipping 470000_3787000: no match in second folder.
# Skipping 470000_3788000: no match in second folder.
# Skipping 470000_3789000: no match in second folder.
# Skipping 470000_3790000: no match in second folder.
# Skipping 470000_3791000: no match in second folder.
# Skipping 470000_3792000: no match in second folder.
# Skipping 470000_3793000: no match in second folder.
# Skipping 470000_3794000: no match in second folder.
# Skipping 470000_3795000: no match in second folder.
# Skipping 470000_3796000: no match in second folder.
# Skipping 470000_3797000: no match in second folder.
# Skipping 470000_3798000: no match in second folder.
# Skipping 470000_3799000: no match in second folder.
# Skipping 470000_3800000: no match in second folder.
# Skipping 470000_3801000: no match in second folder.
# Skipping 470000_3802000: no match in second folder.
# Processed 470000_3803000 (dsm).
# Processed 470000_3804000 (dsm).
# Processed 470000_3805000 (dsm).
# Processed 470000_3806000 (dsm).
# Processed 470000_3807000 (dsm).
# Processed 470000_3808000 (dsm).
# Processed 470000_3809000 (dsm).
# Skipping 471000_3771000: no match in second folder.
# Skipping 471000_3772000: no match in second folder.
# Skipping 471000_3773000: no match in second folder.
# Skipping 471000_3774000: no match in second folder.
# Skipping 471000_3775000: no match in second folder.
# Skipping 471000_3776000: no match in second folder.
# Skipping 471000_3777000: no match in second folder.
# Skipping 471000_3778000: no match in second folder.
# Skipping 471000_3779000: no match in second folder.
# Skipping 471000_3780000: no match in second folder.
# Skipping 471000_3781000: no match in second folder.
# Skipping 471000_3782000: no match in second folder.
# Skipping 471000_3783000: no match in second folder.
# Skipping 471000_3784000: no match in second folder.
# Skipping 471000_3785000: no match in second folder.
# Skipping 471000_3786000: no match in second folder.
# Skipping 471000_3787000: no match in second folder.
# Skipping 471000_3788000: no match in second folder.
# Skipping 471000_3789000: no match in second folder.
# Skipping 471000_3790000: no match in second folder.
# Skipping 471000_3791000: no match in second folder.
# Skipping 471000_3792000: no match in second folder.
# Skipping 471000_3793000: no match in second folder.
# Skipping 471000_3794000: no match in second folder.
# Skipping 471000_3795000: no match in second folder.
# Skipping 471000_3796000: no match in second folder.
# Skipping 471000_3797000: no match in second folder.
# Skipping 471000_3798000: no match in second folder.
# Skipping 471000_3799000: no match in second folder.
# Skipping 471000_3800000: no match in second folder.
# Skipping 471000_3801000: no match in second folder.
# Skipping 471000_3802000: no match in second folder.
# Processed 471000_3803000 (dsm).
# Processed 471000_3804000 (dsm).
# Processed 471000_3805000 (dsm).
# Processed 471000_3806000 (dsm).
# Processed 471000_3807000 (dsm).
# Processed 471000_3808000 (dsm).
# Processed 471000_3809000 (dsm).
# Processed 471000_3810000 (dsm).
# Skipping 472000_3771000: no match in second folder.
# Skipping 472000_3772000: no match in second folder.
# Skipping 472000_3773000: no match in second folder.
# Skipping 472000_3774000: no match in second folder.
# Skipping 472000_3775000: no match in second folder.
# Skipping 472000_3776000: no match in second folder.
# Skipping 472000_3777000: no match in second folder.
# Skipping 472000_3778000: no match in second folder.
# Skipping 472000_3779000: no match in second folder.
# Skipping 472000_3780000: no match in second folder.
# Skipping 472000_3781000: no match in second folder.
# Skipping 472000_3782000: no match in second folder.
# Skipping 472000_3783000: no match in second folder.
# Skipping 472000_3784000: no match in second folder.
# Skipping 472000_3785000: no match in second folder.
# Skipping 472000_3786000: no match in second folder.
# Skipping 472000_3787000: no match in second folder.
# Skipping 472000_3788000: no match in second folder.
# Skipping 472000_3789000: no match in second folder.
# Skipping 472000_3790000: no match in second folder.
# Skipping 472000_3791000: no match in second folder.
# Skipping 472000_3792000: no match in second folder.
# Skipping 472000_3793000: no match in second folder.
# Skipping 472000_3794000: no match in second folder.
# Skipping 472000_3795000: no match in second folder.
# Skipping 472000_3796000: no match in second folder.
# Skipping 472000_3797000: no match in second folder.
# Skipping 472000_3798000: no match in second folder.
# Skipping 472000_3799000: no match in second folder.
# Skipping 472000_3800000: no match in second folder.
# Skipping 472000_3801000: no match in second folder.
# Skipping 472000_3802000: no match in second folder.
# Skipping 472000_3803000: no match in second folder.
# Processed 472000_3804000 (dsm).
# Processed 472000_3805000 (dsm).
# Processed 472000_3806000 (dsm).
# Processed 472000_3807000 (dsm).
# Processed 472000_3808000 (dsm).
# Processed 472000_3809000 (dsm).
# Processed 472000_3810000 (dsm).
# Skipping 473000_3771000: no match in second folder.
# Skipping 473000_3772000: no match in second folder.
# Skipping 473000_3773000: no match in second folder.
# Skipping 473000_3774000: no match in second folder.
# Skipping 473000_3775000: no match in second folder.
# Skipping 473000_3776000: no match in second folder.
# Skipping 473000_3777000: no match in second folder.
# Skipping 473000_3778000: no match in second folder.
# Skipping 473000_3779000: no match in second folder.
# Skipping 473000_3780000: no match in second folder.
# Skipping 473000_3781000: no match in second folder.
# Skipping 473000_3782000: no match in second folder.
# Skipping 473000_3783000: no match in second folder.
# Skipping 473000_3784000: no match in second folder.
# Skipping 473000_3785000: no match in second folder.
# Skipping 473000_3786000: no match in second folder.
# Skipping 473000_3787000: no match in second folder.
# Skipping 473000_3788000: no match in second folder.
# Skipping 473000_3789000: no match in second folder.
# Skipping 473000_3790000: no match in second folder.
# Skipping 473000_3791000: no match in second folder.
# Skipping 473000_3792000: no match in second folder.
# Skipping 473000_3793000: no match in second folder.
# Skipping 473000_3794000: no match in second folder.
# Skipping 473000_3795000: no match in second folder.
# Skipping 473000_3796000: no match in second folder.
# Skipping 473000_3797000: no match in second folder.
# Skipping 473000_3798000: no match in second folder.
# Skipping 473000_3799000: no match in second folder.
# Skipping 473000_3800000: no match in second folder.
# Skipping 473000_3801000: no match in second folder.
# Skipping 473000_3802000: no match in second folder.
# Skipping 473000_3803000: no match in second folder.
# Processed 473000_3804000 (dsm).
# Processed 473000_3805000 (dsm).
# Processed 473000_3806000 (dsm).
# Processed 473000_3807000 (dsm).
# Processed 473000_3808000 (dsm).
# Processed 473000_3809000 (dsm).
# Processed 473000_3810000 (dsm).
# Processed 473000_3811000 (dsm).
# Skipping 474000_3771000: no match in second folder.
# Skipping 474000_3772000: no match in second folder.
# Skipping 474000_3773000: no match in second folder.
# Skipping 474000_3774000: no match in second folder.
# Skipping 474000_3775000: no match in second folder.
# Skipping 474000_3776000: no match in second folder.
# Skipping 474000_3777000: no match in second folder.
# Skipping 474000_3778000: no match in second folder.
# Skipping 474000_3779000: no match in second folder.
# Skipping 474000_3780000: no match in second folder.
# Skipping 474000_3781000: no match in second folder.
# Skipping 474000_3782000: no match in second folder.
# Skipping 474000_3783000: no match in second folder.
# Skipping 474000_3784000: no match in second folder.
# Skipping 474000_3785000: no match in second folder.
# Skipping 474000_3786000: no match in second folder.
# Skipping 474000_3787000: no match in second folder.
# Skipping 474000_3788000: no match in second folder.
# Skipping 474000_3789000: no match in second folder.
# Skipping 474000_3790000: no match in second folder.
# Skipping 474000_3791000: no match in second folder.
# Skipping 474000_3792000: no match in second folder.
# Skipping 474000_3793000: no match in second folder.
# Skipping 474000_3794000: no match in second folder.
# Skipping 474000_3795000: no match in second folder.
# Skipping 474000_3796000: no match in second folder.
# Skipping 474000_3797000: no match in second folder.
# Skipping 474000_3798000: no match in second folder.
# Skipping 474000_3799000: no match in second folder.
# Skipping 474000_3800000: no match in second folder.
# Skipping 474000_3801000: no match in second folder.
# Skipping 474000_3802000: no match in second folder.
# Skipping 474000_3803000: no match in second folder.
# Processed 474000_3804000 (dsm).
# Processed 474000_3805000 (dsm).
# Processed 474000_3806000 (dsm).
# Processed 474000_3807000 (dsm).
# Processed 474000_3808000 (dsm).
# Processed 474000_3809000 (dsm).
# Processed 474000_3810000 (dsm).
# Processed 474000_3811000 (dsm).
# Skipping 475000_3771000: no match in second folder.
# Skipping 475000_3772000: no match in second folder.
# Skipping 475000_3773000: no match in second folder.
# Skipping 475000_3774000: no match in second folder.
# Skipping 475000_3775000: no match in second folder.
# Skipping 475000_3776000: no match in second folder.
# Skipping 475000_3777000: no match in second folder.
# Skipping 475000_3778000: no match in second folder.
# Skipping 475000_3779000: no match in second folder.
# Skipping 475000_3780000: no match in second folder.
# Skipping 475000_3781000: no match in second folder.
# Skipping 475000_3782000: no match in second folder.
# Skipping 475000_3783000: no match in second folder.
# Skipping 475000_3784000: no match in second folder.
# Skipping 475000_3785000: no match in second folder.
# Skipping 475000_3786000: no match in second folder.
# Skipping 475000_3787000: no match in second folder.
# Skipping 475000_3788000: no match in second folder.
# Skipping 475000_3789000: no match in second folder.
# Skipping 475000_3790000: no match in second folder.
# Skipping 475000_3791000: no match in second folder.
# Skipping 475000_3792000: no match in second folder.
# Skipping 475000_3793000: no match in second folder.
# Skipping 475000_3794000: no match in second folder.
# Skipping 475000_3795000: no match in second folder.
# Skipping 475000_3796000: no match in second folder.
# Skipping 475000_3797000: no match in second folder.
# Skipping 475000_3798000: no match in second folder.
# Skipping 475000_3799000: no match in second folder.
# Skipping 475000_3800000: no match in second folder.
# Skipping 475000_3801000: no match in second folder.
# Skipping 475000_3802000: no match in second folder.
# Skipping 475000_3803000: no match in second folder.
# Processed 475000_3804000 (dsm).
# Processed 475000_3805000 (dsm).
# Processed 475000_3806000 (dsm).
# Processed 475000_3807000 (dsm).
# Processed 475000_3808000 (dsm).
# Processed 475000_3809000 (dsm).
# Processed 475000_3810000 (dsm).
# Processed 475000_3811000 (dsm).
# Skipping 476000_3771000: no match in second folder.
# Skipping 476000_3772000: no match in second folder.
# Skipping 476000_3773000: no match in second folder.
# Skipping 476000_3774000: no match in second folder.
# Skipping 476000_3775000: no match in second folder.
# Skipping 476000_3776000: no match in second folder.
# Skipping 476000_3777000: no match in second folder.
# Skipping 476000_3778000: no match in second folder.
# Skipping 476000_3779000: no match in second folder.
# Skipping 476000_3780000: no match in second folder.
# Skipping 476000_3781000: no match in second folder.
# Skipping 476000_3782000: no match in second folder.
# Skipping 476000_3783000: no match in second folder.
# Skipping 476000_3784000: no match in second folder.
# Skipping 476000_3785000: no match in second folder.
# Skipping 476000_3786000: no match in second folder.
# Skipping 476000_3787000: no match in second folder.
# Skipping 476000_3788000: no match in second folder.
# Skipping 476000_3789000: no match in second folder.
# Skipping 476000_3790000: no match in second folder.
# Skipping 476000_3791000: no match in second folder.
# Skipping 476000_3792000: no match in second folder.
# Skipping 476000_3793000: no match in second folder.
# Skipping 476000_3794000: no match in second folder.
# Skipping 476000_3795000: no match in second folder.
# Skipping 476000_3796000: no match in second folder.
# Skipping 476000_3797000: no match in second folder.
# Skipping 476000_3798000: no match in second folder.
# Skipping 476000_3799000: no match in second folder.
# Skipping 476000_3800000: no match in second folder.
# Skipping 476000_3801000: no match in second folder.
# Skipping 476000_3802000: no match in second folder.
# Processed 476000_3803000 (dsm).
# Processed 476000_3804000 (dsm).
# Processed 476000_3805000 (dsm).
# Processed 476000_3806000 (dsm).
# Processed 476000_3807000 (dsm).
# Processed 476000_3808000 (dsm).
# Processed 476000_3809000 (dsm).
# ...
# Overviews: 476000_3809000_rumple_diff.tif
# Overviews: 476000_3810000_rumple_diff.tif
# Overviews: 476000_3811000_rumple_diff.tif
# Overviews: 476000_3812000_rumple_diff.tif
# Overviews: 477000_3803000_rumple_diff.tif
# Overviews: 477000_3804000_rumple_diff.tif
# Overviews: 477000_3805000_rumple_diff.tif
# Overviews: 477000_3806000_rumple_diff.tif
# Overviews: 477000_3807000_rumple_diff.tif
# Overviews: 477000_3808000_rumple_diff.tif
# Overviews: 477000_3809000_rumple_diff.tif
# Overviews: 477000_3810000_rumple_diff.tif
# Overviews: 477000_3811000_rumple_diff.tif
# Overviews: 477000_3812000_rumple_diff.tif
# Overviews: 478000_3802000_rumple_diff.tif
# Overviews: 478000_3803000_rumple_diff.tif
# Overviews: 478000_3804000_rumple_diff.tif
# Overviews: 478000_3805000_rumple_diff.tif
# Overviews: 478000_3806000_rumple_diff.tif
# Overviews: 478000_3807000_rumple_diff.tif
# Overviews: 478000_3808000_rumple_diff.tif
# Overviews: 478000_3809000_rumple_diff.tif
# Overviews: 478000_3810000_rumple_diff.tif
# Overviews: 479000_3802000_rumple_diff.tif
# Overviews: 479000_3803000_rumple_diff.tif
# Overviews: 479000_3804000_rumple_diff.tif
# Overviews: 479000_3805000_rumple_diff.tif
# Overviews: 479000_3806000_rumple_diff.tif
# Overviews: 479000_3807000_rumple_diff.tif
# Overviews: 479000_3808000_rumple_diff.tif
# Overviews: 479000_3809000_rumple_diff.tif
# Overviews: 479000_3810000_rumple_diff.tif
# Overviews: 480000_3801000_rumple_diff.tif
# Overviews: 480000_3802000_rumple_diff.tif
# Overviews: 512000_3777000_rumple_diff.tif
# Overviews: 512000_3778000_rumple_diff.tif
# Overviews: 512000_3779000_rumple_diff.tif
# Overviews: 512000_3780000_rumple_diff.tif
# Overviews: 512000_3781000_rumple_diff.tif
# Overviews: 512000_3782000_rumple_diff.tif
# Overviews: 512000_3783000_rumple_diff.tif
# Overviews: 512000_3784000_rumple_diff.tif
# Overviews: 512000_3785000_rumple_diff.tif
# Overviews: 512000_3786000_rumple_diff.tif
# Overviews: 512000_3787000_rumple_diff.tif
# Overviews: 512000_3788000_rumple_diff.tif
# Overviews: 512000_3789000_rumple_diff.tif
# Overviews: 512000_3790000_rumple_diff.tif
# Overviews: 512000_3791000_rumple_diff.tif
# Overviews: 512000_3792000_rumple_diff.tif
# Overviews: 513000_3774000_rumple_diff.tif
# Overviews: 513000_3775000_rumple_diff.tif
# Overviews: 513000_3776000_rumple_diff.tif
# Overviews: 513000_3777000_rumple_diff.tif
# Overviews: 513000_3778000_rumple_diff.tif
# Overviews: 513000_3779000_rumple_diff.tif
# Overviews: 513000_3780000_rumple_diff.tif
# VRT created: C:/Users/sreeja/Documents/AZ Dataset Analysis/Differences\DSM_Diff_2019.vrt
# VRT created: C:/Users/sreeja/Documents/AZ Dataset Analysis/Differences\DTM_Diff_2019.vrt
# VRT created: C:/Users/sreeja/Documents/AZ Dataset Analysis/Differences\Rumple_Diff_2019.vrt

# %%
def index_files(folder, year_tag, suffix_key):
    """
    Index raster files in a folder by stripping year_tag and suffix_key from filenames.
    Args:
        folder (str): Path to the directory containing raster files.
        year_tag (str): Year identifier in filenames (e.g., '2017').
        suffix_key (str): Metric suffix key in filenames (e.g., 'chm').
    Returns:
        dict: Mapping from tile base name to full file path.
    """
    index = {}
    suffix = f"_{year_tag}_{suffix_key}.tif"
    for file in os.listdir(folder):
        if file.endswith(suffix) and "hillshade" not in file.lower():
            base = file.replace(suffix, "")
            index[base] = os.path.join(folder, file)
    return index


def parse_coords_from_filename(tile_name):
    """
    Extract bottom-left coordinates from a tile name formatted as 'X_Y'.
    Args:
        tile_name (str): Tile identifier string.
    Returns:
        tuple: (x_min, y_min) as integers.
    """
    parts = tile_name.split("_")
    if len(parts) < 2:
        raise ValueError(f"Invalid tile name format: {tile_name}")
    return int(parts[0]), int(parts[1])


def compute_extent_from_tile(tile_name, tile_size, buffer):
    """
    Compute bounding box extent for a tile with buffer.
    Args:
        tile_name (str): Tile identifier string.
        tile_size (tuple): (width, height) in same units as coordinates.
        buffer (float): Buffer distance to extend the extent.
    Returns:
        list: [xmin, ymin, xmax, ymax]
    """
    x_min, y_min = parse_coords_from_filename(tile_name)
    xmin = x_min - buffer
    ymin = y_min - buffer
    xmax = x_min + tile_size[0] + buffer
    ymax = y_min + tile_size[1] + buffer
    return [xmin, ymin, xmax, ymax]


def warp_if_needed(src_path, extent, resolution, dest_path):
    """
    Warp a raster to a specified extent and resolution.
    Args:
        src_path (str): Source raster file path.
        extent (list): [xmin, ymin, xmax, ymax].
        resolution (tuple or None): (x_res, y_res) or None to keep source resolution.
        dest_path (str): Path to save warped raster.
    Returns:
        str: Path to the warped raster (dest_path).
    """
    cmd = [
        "gdalwarp", "-overwrite", "-of", "GTiff",
        "-te", *map(str, extent),
        "-r", "near",
        "-srcnodata", "nan",
        "-dstnodata", "nan",
        "-co", "TILED=YES",
        "-co", "COMPRESS=LZW"
    ]
    if resolution:
        cmd += ["-tr", str(resolution[0]), str(abs(resolution[1]))]
    cmd += [src_path, dest_path]
    subprocess.run(cmd, check=True)
    return dest_path


def compute_difference(folder1, tag1, folder2, tag2, output_dir, tile_size, buffer, resolution, suffix_key):
    """
    Compute masked difference (A - B) between corresponding tiles in two folders.
    Args:
        folder1 (str): Path to first timepoint metric folder.
        tag1 (str): Year tag for first dataset.
        folder2 (str): Path to second timepoint metric folder.
        tag2 (str): Year tag for second dataset.
        output_dir (str): Directory to store difference outputs.
        tile_size (tuple): (width, height) of each tile.
        buffer (float): Buffer distance around each tile.
        resolution (tuple or None): Target resolution for warping.
        suffix_key (str): Key suffix for metric (e.g., 'chm').
    """
    os.makedirs(output_dir, exist_ok=True)
    idx1 = index_files(folder1, tag1, suffix_key)
    idx2 = index_files(folder2, tag2, suffix_key)

    processed, skipped = 0, 0
    for key in sorted(idx1):
        if key not in idx2:
            print(f"Skipping {key}: no match in second folder.")
            skipped += 1
            continue
        f1, f2 = idx1[key], idx2[key]
        out_file = os.path.join(output_dir, f"{key}_{suffix_key}_diff.tif")
        temp1 = out_file.replace(".tif", f"_tmp_{tag1}.tif")
        temp2 = out_file.replace(".tif", f"_tmp_{tag2}.tif")
        try:
            ext = compute_extent_from_tile(key, tile_size, buffer)
            warp_if_needed(f1, ext, resolution, temp1)
            warp_if_needed(f2, ext, resolution, temp2)

            raw_diff = out_file.replace(".tif", "_raw.tif")
            filt = out_file.replace(".tif", "_filtered.tif")

            subprocess.run([
                "gdal_calc",
                "-A", temp2,
                "-B", temp1,
                "--calc=A-B",
                "--outfile", raw_diff,
                "--type", "Float32",
                "--overwrite"
            ], check=True)

            subprocess.run([
                "gdal_calc",
                "-A", raw_diff,
                "--calc", "where((A>=-100)&(A<=100),A,-9999)",
                "--NoDataValue", "-9999",
                "--type", "Float32",
                "--co", "TILED=YES",
                "--co", "COMPRESS=LZW",
                "--overwrite",
                "--outfile", filt
            ], check=True)

            os.replace(filt, out_file)
            subprocess.run(["gdal_edit", "-a_nodata", "-9999", out_file], check=True)
            os.remove(raw_diff)
            os.remove(temp1)
            os.remove(temp2)

            print(f"Processed {key} ({suffix_key}).")
            processed += 1
        except Exception as e:
            print(f"Error processing {key}: {e}")
            traceback.print_exc()
            skipped += 1

    print(f"Done: {processed} processed, {skipped} skipped.")


def add_overviews(parent_dir, levels):
    """
    Add internal overviews to all TIFFs under a base directory.
    Args:
        parent_dir (str): Root directory containing metric/Diff subfolders.
        levels (list[int]): Powers-of-two overview levels (e.g., [2,4,8,16,32]).
    """
    for root, _, files in os.walk(parent_dir):
        for f in files:
            if f.lower().endswith('.tif') and 'vrt' not in f:
                path = os.path.join(root, f)
                cmd = ['gdaladdo', '-r', 'average', path] + list(map(str, levels))
                try:
                    subprocess.run(cmd, check=True, capture_output=True)
                    print(f"Overviews: {f}")
                except subprocess.CalledProcessError as e:
                    print(f"Failed overview for {f}")


def build_vrt(parent_dir, metric_folder, prefix, tag, nodata='-9999'):
    """
    Build a VRT mosaic from all TIFFs in a subfolder.
    Args:
        parent_dir (str): Root directory containing metric/Diff subfolders.
        metric_folder (str): Subfolder name (e.g., 'CHM_Diff').
        prefix (str): Prefix for VRT filename.
        tag (str): Tag (e.g., '2019') appended to VRT name.
        nodata (str): NoData value to hide.
    """
    sub = os.path.join(parent_dir, metric_folder)
    files = sorted([os.path.join(sub, f) for f in os.listdir(sub) if f.endswith('.tif')])
    if not files:
        return
    filelist = os.path.join(parent_dir, f"{prefix}_{tag}_filelist.txt")
    with open(filelist, 'w') as fh:
        for p in files:
            fh.write(p.replace('\\', '/') + '\n')
    vrt = os.path.join(parent_dir, f"{prefix}_{tag}.vrt")
    cmd = [
        'gdalbuildvrt',
        '-srcnodata', nodata,
        '-vrtnodata', nodata,
        '-hidenodata',
        '-input_file_list', filelist,
        vrt
    ]
    try:
        subprocess.run(cmd, check=True, capture_output=True)
        print(f"VRT created: {vrt}")
    except subprocess.CalledProcessError as e:
        print(f"VRT error for {metric_folder}: {e.stderr}")


def run(
    folder1_base,
    folder2_base,
    tag1,
    tag2,
    output_base,
    tile_size=(1000, 1000),
    buffer=20,
    resolution=None,
    overview_levels=[2,4,8,16,32],
    metrics=None
):
    """
    Execute the full pipeline end-to-end without requiring CLI args.
    """
    if metrics is None:
        metrics = [
            'CHM_normalized_tiles','Canopy_Cover_tiles','Density_Tiles',
            'DSM_tiles','DTM_tiles','Rumple_tiles'
        ]

    for metric in metrics:
        compute_difference(
            os.path.join(folder1_base, metric), tag1,
            os.path.join(folder2_base, metric), tag2,
            os.path.join(output_base, metric.replace('_tiles','_Diff')),
            tile_size, buffer, resolution, metric.replace('_tiles','').lower()
        )

    add_overviews(output_base, overview_levels)

    for metric in metrics:
        build_vrt(output_base, metric.replace('_tiles','_Diff'), metric.replace('_tiles','_Diff'), tag2)


if __name__ == '__main__':
    # === Configuration ===
    folder1_base = r"C:/Users/sreeja/Documents/AZ Dataset Analysis/extracted_2017_metrics"
    folder2_base = r"C:/Users/sreeja/Documents/AZ Dataset Analysis/extracted_2019_metrics"
    tag1 = "2017"
    tag2 = "2019"
    output_base = r"C:/Users/sreeja/Documents/AZ Dataset Analysis/Differences"
    tile_size = (1000, 1000)
    buffer = 20
    resolution = None  # e.g. (1.0, 1.0) or None for native
    overview_levels = [2,4,8,16,32]
    metrics = [
        'CHM_normalized_tiles','Canopy_Cover_tiles','Density_Tiles',
        'DSM_tiles','DTM_tiles','Rumple_tiles'
    ]

    run(
        folder1_base,
        folder2_base,
        tag1,
        tag2,
        output_base,
        tile_size,
        buffer,
        resolution,
        overview_levels,
        metrics
    )
